# %%
# หมายเหตุ : งานปกติโปรแกรม R ใช้ print หรือ cat แต่บางทีใช้เว็บนี้แล้วมีติดบั๊ค สามารถแก้เฉพาะกิจโดยเปลี่ยนจาก print เป็น message แทน

# HW01 : Chatbot
message("Welcome to Lazada online shopping🛍️")
message("Hello, I'm Laza. Nice to meet you, sir!😊")
message("We are at your service")
message("You can choose a number:")
message("Number [1] : Track the status of your order")
message("Number [2] : Frequently asked questions")
message("Number [3] : Want to contact staff of Lazada")
message("Number [4] : Want to give suggestions")
message("Number [5] : Want to find products")
message("Number [6] : You're lonely and want to find someone to talk together")

question <- function() {
  text = readline("Your choose :")
  if (text == "1") {
      readline("What is your order number? :")
      readline("What is your phone number? :")
      message("Wait a minute, we are processing")
  }
  if (text == "2") {
    message("[1] Procedure for changing delivery address")
    message("[2] Procedure for requesting a refund")
    message("[3] Procedure for returning goods")
    message("[4] Procedure for cheating complaints from store")
    asking <- readline("Your question :")
    message("Wait a minute, we are taking you to the page of that article")
  }
  if (text == "3") {
    message("Give us a second, we are contacting staff for you")
  }
  if (text == "4") {
    readline("You can type any comments :")
    message("Thank you for the suggestion, we will take your comments to improve")
  }
  if (text == "5") {
    message("[F] : Food and beverage category")
    message("[H] : Household items category")
    message("[C] : Cosmetics category")
    message("[B] : Children's category")
    message("[P] : Plants category")
    product <- readline("What kind of product are you looking for? :")
    if (toupper(product) == "F" | toupper(product) == "H" |toupper(product) == "C" | toupper(product) == "B" | toupper(product) == "P") {
      message("Just a minute, we are taking you to that category page")
    }
  }
  if (text == "6") {
    name <- readline("Hi! what is your name? :")
    message(paste("Nice to meet you, ", toupper(name)))
    message("Let's play Q&A !")
    readline("1. How's it going today? :")
    message("Don't forget to rest")
    old <- readline("2. How old are you? :")
    if (old <= 15) {
      message("Take care! Don't be up too late!")
    } else if (old >= 16 & old <= 30) {
      message("If you are tired, don't forget to find something delicious to eat")
    } else if (old >= 31 & old <= 50) {
      message("Find some time to work out")
      message("You can buy fitness equipment from Lazada🤭")
    } else {
      message("Don't lift too heavy! Take care of your back!")
    }
    ask <- readline("3. Do you like shopping online or offline?")
    if (tolower(ask) == "online") {
      online <- readline("Wow! Do you like shopping at lazada? :")
      if (tolower(online) == "yes") {
        message("Thank you for coming to support us often!🥰")
      } else {
        message("What a pity! we are waiting for you to shop at Lazada🤗")
      }
    }
    if (tolower(ask) == "offline") {
      message("Don't forget to shop at Lazada, there are many discount codes😉")
    }
  }
}
question()

message("---------------------------------------")
message("Thank you for choosing to use our service")
message("---------------------------------------")
message("Would you like us to help you again?")
message("You can choose [1] for start asking us again or")
message("        choose [2] for stop asking us")
newRound <- readline("You choose :")
  if (newRound == 1) {
      message("It's been a pleasure serving you")
      question()
  } else {
      message("See you next time!")
      break
  }
# Out:
# Welcome to Lazada online shopping🛍️
#
# Hello, I'm Laza. Nice to meet you, sir!😊
#
# We are at your service
#
# You can choose a number:
#
# Number [1] : Track the status of your order
#
# Number [2] : Frequently asked questions
#
# Number [3] : Want to contact staff of Lazada
#
# Number [4] : Want to give suggestions
#
# Number [5] : Want to find products
#
# Number [6] : You're lonely and want to find someone to talk together
#
# Nice to meet you,  PLOY
#
# Let's play Q&A !
#
# Don't forget to rest
#
# If you are tired, don't forget to find something delicious to eat
#
# Thank you for coming to support us often!🥰
#
# ---------------------------------------
#
# Thank you for choosing to use our service
#
# ---------------------------------------
#
# Would you like us to help you again?
#
# You can choose [1] for start asking us again or
#
#         choose [2] for stop asking us
